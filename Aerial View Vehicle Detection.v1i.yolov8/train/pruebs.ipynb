# %% [markdown]
# ## Cambiar etiquetas para que todas sean 0

# %%
import os

def unificar_clases():
    """
    Recorre todos los archivos .txt dentro de la carpeta 'labels'
    y cambia cualquier clase a '0' (asumiendo que tenemos una sola clase).
    """
    labels_dir = "labels"  # carpeta donde están los .txt

    # Verifica que exista la carpeta 'labels'
    if not os.path.isdir(labels_dir):
        print(f"No se encontró la carpeta: {labels_dir}")
        return

    # Recorre recursivamente la carpeta 'labels'
    for root, dirs, files in os.walk(labels_dir):
        for file in files:
            if file.endswith(".txt"):
                file_path = os.path.join(root, file)
                # Lee las líneas originales
                with open(file_path, 'r') as f:
                    lines = f.readlines()

                nuevas_lineas = []
                for line in lines:
                    tokens = line.strip().split()
                    # Asegura que tenga al menos 5 valores (clase + 4 coords)
                    if len(tokens) < 5:
                        continue
                    # Reemplaza la clase original por '0'
                    nueva_linea = "0 " + " ".join(tokens[1:]) + "\n"
                    nuevas_lineas.append(nueva_linea)

                # Sobrescribe el archivo con la nueva clase
                with open(file_path, 'w') as f:
                    f.writelines(nuevas_lineas)

                print(f"Archivo actualizado: {file_path}")

if __name__ == "__main__":
    unificar_clases()
    print("Proceso completado: todas las clases se han establecido en '0'.")
# Out:
# Archivo actualizado: labels\imagen1.txt
# Archivo actualizado: labels\imagen10.txt
# Archivo actualizado: labels\imagen100.txt
# Archivo actualizado: labels\imagen1000.txt
# Archivo actualizado: labels\imagen1001.txt
# Archivo actualizado: labels\imagen1002.txt
# Archivo actualizado: labels\imagen1003.txt
# Archivo actualizado: labels\imagen1004.txt
# Archivo actualizado: labels\imagen1005.txt
# Archivo actualizado: labels\imagen1006.txt
# Archivo actualizado: labels\imagen1007.txt
# Archivo actualizado: labels\imagen1008.txt
# Archivo actualizado: labels\imagen1009.txt
# Archivo actualizado: labels\imagen101.txt
# Archivo actualizado: labels\imagen1010.txt
# Archivo actualizado: labels\imagen1011.txt
# Archivo actualizado: labels\imagen1012.txt
# Archivo actualizado: labels\imagen1013.txt
# Archivo actualizado: labels\imagen1014.txt
# Archivo actualizado: labels\imagen1015.txt
# Archivo actualizado: labels\imagen1016.txt
# Archivo actualizado: labels\imagen1017.txt
# Archivo actualizado: labels\imagen1018.txt
# Archivo actualizado: labels\imagen1019.txt
# Archivo actualizado: labels\imagen102.txt
# Archivo actualizado: labels\imagen1020.txt
# Archivo actualizado: labels\imagen1021.txt
# Archivo actualizado: labels\imagen1022.txt
# Archivo actualizado: labels\imagen1023.txt
# Archivo actualizado: labels\imagen1024.txt
# Archivo actualizado: labels\imagen1025.txt
# Archivo actualizado: labels\imagen1026.txt
# Archivo actualizado: labels\imagen1027.txt
# Archivo actualizado: labels\imagen1028.txt
# Archivo actualizado: labels\imagen1029.txt
# Archivo actualizado: labels\imagen103.txt
# Archivo actualizado: labels\imagen1030.txt
# Archivo actualizado: labels\imagen1031.txt
# Archivo actualizado: labels\imagen1032.txt
# Archivo actualizado: labels\imagen1033.txt
# Archivo actualizado: labels\imagen1034.txt
# Archivo actualizado: labels\imagen1035.txt
# Archivo actualizado: labels\imagen1036.txt
# Archivo actualizado: labels\imagen1037.txt
# Archivo actualizado: labels\imagen1038.txt
# Archivo actualizado: labels\imagen1039.txt
# Archivo actualizado: labels\imagen104.txt
# Archivo actualizado: labels\imagen1040.txt
# Archivo actualizado: labels\imagen1041.txt
# Archivo actualizado: labels\imagen1042.txt
# Archivo actualizado: labels\imagen1043.txt
# Archivo actualizado: labels\imagen1044.txt
# Archivo actualizado: labels\imagen1045.txt
# Archivo actualizado: labels\imagen1046.txt
# Archivo actualizado: labels\imagen1047.txt
# Archivo actualizado: labels\imagen1048.txt
# Archivo actualizado: labels\imagen1049.txt
# Archivo actualizado: labels\imagen105.txt
# Archivo actualizado: labels\imagen1050.txt
# Archivo actualizado: labels\imagen1051.txt
# Archivo actualizado: labels\imagen1052.txt
# Archivo actualizado: labels\imagen1053.txt
# Archivo actualizado: labels\imagen1054.txt
# Archivo actualizado: labels\imagen1055.txt
# Archivo actualizado: labels\imagen1056.txt
# Archivo actualizado: labels\imagen1057.txt
# Archivo actualizado: labels\imagen1058.txt
# Archivo actualizado: labels\imagen1059.txt
# Archivo actualizado: labels\imagen106.txt
# Archivo actualizado: labels\imagen1060.txt
# Archivo actualizado: labels\imagen1061.txt
# Archivo actualizado: labels\imagen1062.txt
# Archivo actualizado: labels\imagen1063.txt
# Archivo actualizado: labels\imagen1064.txt
# Archivo actualizado: labels\imagen1065.txt
# Archivo actualizado: labels\imagen1066.txt
# Archivo actualizado: labels\imagen1067.txt
# Archivo actualizado: labels\imagen1068.txt
# Archivo actualizado: labels\imagen1069.txt
# Archivo actualizado: labels\imagen107.txt
# Archivo actualizado: labels\imagen1070.txt
# Archivo actualizado: labels\imagen1071.txt
# Archivo actualizado: labels\imagen1072.txt
# Archivo actualizado: labels\imagen1073.txt
# Archivo actualizado: labels\imagen1074.txt
# Archivo actualizado: labels\imagen1075.txt
# Archivo actualizado: labels\imagen1076.txt
# Archivo actualizado: labels\imagen1077.txt
# Archivo actualizado: labels\imagen1078.txt
# Archivo actualizado: labels\imagen1079.txt
# Archivo actualizado: labels\imagen108.txt
# Archivo actualizado: labels\imagen1080.txt
# Archivo actualizado: labels\imagen1081.txt
# Archivo actualizado: labels\imagen1082.txt
# Archivo actualizado: labels\imagen1083.txt
# Archivo actualizado: labels\imagen1084.txt
# Archivo actualizado: labels\imagen1085.txt
# Archivo actualizado: labels\imagen1086.txt
# Archivo actualizado: labels\imagen1087.txt
# Archivo actualizado: labels\imagen1088.txt
# Archivo actualizado: labels\imagen1089.txt
# Archivo actualizado: labels\imagen109.txt
# Archivo actualizado: labels\imagen1090.txt
# Archivo actualizado: labels\imagen1091.txt
# Archivo actualizado: labels\imagen1092.txt
# Archivo actualizado: labels\imagen1093.txt
# Archivo actualizado: labels\imagen1094.txt
# Archivo actualizado: labels\imagen1095.txt
# Archivo actualizado: labels\imagen1096.txt
# Archivo actualizado: labels\imagen1097.txt
# Archivo actualizado: labels\imagen1098.txt
# Archivo actualizado: labels\imagen1099.txt
# Archivo actualizado: labels\imagen11.txt
# Archivo actualizado: labels\imagen110.txt
# Archivo actualizado: labels\imagen1100.txt
# Archivo actualizado: labels\imagen1101.txt
# Archivo actualizado: labels\imagen1102.txt
# Archivo actualizado: labels\imagen1103.txt
# Archivo actualizado: labels\imagen1104.txt
# Archivo actualizado: labels\imagen1105.txt
# Archivo actualizado: labels\imagen1106.txt
# Archivo actualizado: labels\imagen1107.txt
# Archivo actualizado: labels\imagen1108.txt
# Archivo actualizado: labels\imagen1109.txt
# Archivo actualizado: labels\imagen111.txt
# Archivo actualizado: labels\imagen1110.txt
# Archivo actualizado: labels\imagen1111.txt
# Archivo actualizado: labels\imagen1112.txt
# Archivo actualizado: labels\imagen1113.txt
# Archivo actualizado: labels\imagen1114.txt
# Archivo actualizado: labels\imagen1115.txt
# Archivo actualizado: labels\imagen1116.txt
# Archivo actualizado: labels\imagen1117.txt
# Archivo actualizado: labels\imagen1118.txt
# Archivo actualizado: labels\imagen1119.txt
# Archivo actualizado: labels\imagen112.txt
# Archivo actualizado: labels\imagen1120.txt
# Archivo actualizado: labels\imagen1121.txt
# Archivo actualizado: labels\imagen1122.txt
# Archivo actualizado: labels\imagen1123.txt
# Archivo actualizado: labels\imagen1124.txt
# Archivo actualizado: labels\imagen1125.txt
# Archivo actualizado: labels\imagen1126.txt
# Archivo actualizado: labels\imagen1127.txt
# Archivo actualizado: labels\imagen1128.txt
# Archivo actualizado: labels\imagen1129.txt
# Archivo actualizado: labels\imagen113.txt
# Archivo actualizado: labels\imagen1130.txt
# Archivo actualizado: labels\imagen1131.txt
# Archivo actualizado: labels\imagen1132.txt
# Archivo actualizado: labels\imagen1133.txt
# Archivo actualizado: labels\imagen1134.txt
# Archivo actualizado: labels\imagen1135.txt
# Archivo actualizado: labels\imagen1136.txt
# Archivo actualizado: labels\imagen1137.txt
# Archivo actualizado: labels\imagen1138.txt
# Archivo actualizado: labels\imagen1139.txt
# Archivo actualizado: labels\imagen114.txt
# Archivo actualizado: labels\imagen1140.txt
# Archivo actualizado: labels\imagen1141.txt
# Archivo actualizado: labels\imagen1142.txt
# Archivo actualizado: labels\imagen1143.txt
# Archivo actualizado: labels\imagen1144.txt
# Archivo actualizado: labels\imagen1145.txt
# Archivo actualizado: labels\imagen1146.txt
# Archivo actualizado: labels\imagen1147.txt
# Archivo actualizado: labels\imagen1148.txt
# Archivo actualizado: labels\imagen1149.txt
# Archivo actualizado: labels\imagen115.txt
# Archivo actualizado: labels\imagen1150.txt
# Archivo actualizado: labels\imagen1151.txt
# Archivo actualizado: labels\imagen1152.txt
# Archivo actualizado: labels\imagen1153.txt
# Archivo actualizado: labels\imagen1154.txt
# Archivo actualizado: labels\imagen1155.txt
# Archivo actualizado: labels\imagen1156.txt
# Archivo actualizado: labels\imagen1157.txt
# Archivo actualizado: labels\imagen1158.txt
# Archivo actualizado: labels\imagen1159.txt
# Archivo actualizado: labels\imagen116.txt
# Archivo actualizado: labels\imagen1160.txt
# Archivo actualizado: labels\imagen1161.txt
# Archivo actualizado: labels\imagen1162.txt
# Archivo actualizado: labels\imagen1163.txt
# Archivo actualizado: labels\imagen1164.txt
# Archivo actualizado: labels\imagen1165.txt
# Archivo actualizado: labels\imagen1166.txt
# Archivo actualizado: labels\imagen1167.txt
# Archivo actualizado: labels\imagen1168.txt
# Archivo actualizado: labels\imagen1169.txt
# Archivo actualizado: labels\imagen117.txt
# Archivo actualizado: labels\imagen1170.txt
# Archivo actualizado: labels\imagen1171.txt
# Archivo actualizado: labels\imagen1172.txt
# Archivo actualizado: labels\imagen1173.txt
# Archivo actualizado: labels\imagen1174.txt
# Archivo actualizado: labels\imagen1175.txt
# Archivo actualizado: labels\imagen1176.txt
# Archivo actualizado: labels\imagen1177.txt
# Archivo actualizado: labels\imagen1178.txt
# Archivo actualizado: labels\imagen1179.txt
# Archivo actualizado: labels\imagen118.txt
# Archivo actualizado: labels\imagen1180.txt
# Archivo actualizado: labels\imagen1181.txt
# Archivo actualizado: labels\imagen1182.txt
# Archivo actualizado: labels\imagen1183.txt
# Archivo actualizado: labels\imagen1184.txt
# Archivo actualizado: labels\imagen1185.txt
# Archivo actualizado: labels\imagen1186.txt
# Archivo actualizado: labels\imagen1187.txt
# Archivo actualizado: labels\imagen1188.txt
# Archivo actualizado: labels\imagen1189.txt
# Archivo actualizado: labels\imagen119.txt
# Archivo actualizado: labels\imagen1190.txt
# Archivo actualizado: labels\imagen1191.txt
# Archivo actualizado: labels\imagen1192.txt
# Archivo actualizado: labels\imagen1193.txt
# Archivo actualizado: labels\imagen1194.txt
# Archivo actualizado: labels\imagen1195.txt
# Archivo actualizado: labels\imagen1196.txt
# Archivo actualizado: labels\imagen1197.txt
# Archivo actualizado: labels\imagen1198.txt
# Archivo actualizado: labels\imagen12.txt
# Archivo actualizado: labels\imagen120.txt
# Archivo actualizado: labels\imagen121.txt
# Archivo actualizado: labels\imagen122.txt
# Archivo actualizado: labels\imagen123.txt
# Archivo actualizado: labels\imagen124.txt
# Archivo actualizado: labels\imagen125.txt
# Archivo actualizado: labels\imagen126.txt
# Archivo actualizado: labels\imagen127.txt
# Archivo actualizado: labels\imagen128.txt
# Archivo actualizado: labels\imagen129.txt
# Archivo actualizado: labels\imagen13.txt
# Archivo actualizado: labels\imagen130.txt
# Archivo actualizado: labels\imagen131.txt
# Archivo actualizado: labels\imagen132.txt
# Archivo actualizado: labels\imagen133.txt
# Archivo actualizado: labels\imagen134.txt
# Archivo actualizado: labels\imagen135.txt
# Archivo actualizado: labels\imagen136.txt
# Archivo actualizado: labels\imagen137.txt
# Archivo actualizado: labels\imagen138.txt
# Archivo actualizado: labels\imagen139.txt
# Archivo actualizado: labels\imagen14.txt
# Archivo actualizado: labels\imagen140.txt
# Archivo actualizado: labels\imagen141.txt
# Archivo actualizado: labels\imagen142.txt
# Archivo actualizado: labels\imagen143.txt
# Archivo actualizado: labels\imagen144.txt
# Archivo actualizado: labels\imagen145.txt
# Archivo actualizado: labels\imagen146.txt
# Archivo actualizado: labels\imagen147.txt
# Archivo actualizado: labels\imagen148.txt
# Archivo actualizado: labels\imagen149.txt
# Archivo actualizado: labels\imagen15.txt
# Archivo actualizado: labels\imagen150.txt
# Archivo actualizado: labels\imagen151.txt
# Archivo actualizado: labels\imagen152.txt
# Archivo actualizado: labels\imagen153.txt
# Archivo actualizado: labels\imagen154.txt
# Archivo actualizado: labels\imagen155.txt
# Archivo actualizado: labels\imagen156.txt
# Archivo actualizado: labels\imagen157.txt
# Archivo actualizado: labels\imagen158.txt
# Archivo actualizado: labels\imagen159.txt
# Archivo actualizado: labels\imagen16.txt
# Archivo actualizado: labels\imagen160.txt
# Archivo actualizado: labels\imagen161.txt
# Archivo actualizado: labels\imagen162.txt
# Archivo actualizado: labels\imagen163.txt
# Archivo actualizado: labels\imagen164.txt
# Archivo actualizado: labels\imagen165.txt
# Archivo actualizado: labels\imagen166.txt
# Archivo actualizado: labels\imagen167.txt
# Archivo actualizado: labels\imagen168.txt
# Archivo actualizado: labels\imagen169.txt
# Archivo actualizado: labels\imagen17.txt
# Archivo actualizado: labels\imagen170.txt
# Archivo actualizado: labels\imagen171.txt
# Archivo actualizado: labels\imagen172.txt
# Archivo actualizado: labels\imagen173.txt
# Archivo actualizado: labels\imagen174.txt
# Archivo actualizado: labels\imagen175.txt
# Archivo actualizado: labels\imagen176.txt
# Archivo actualizado: labels\imagen177.txt
# Archivo actualizado: labels\imagen178.txt
# Archivo actualizado: labels\imagen179.txt
# Archivo actualizado: labels\imagen18.txt
# Archivo actualizado: labels\imagen180.txt
# Archivo actualizado: labels\imagen181.txt
# Archivo actualizado: labels\imagen182.txt
# Archivo actualizado: labels\imagen183.txt
# Archivo actualizado: labels\imagen184.txt
# Archivo actualizado: labels\imagen185.txt
# Archivo actualizado: labels\imagen186.txt
# Archivo actualizado: labels\imagen187.txt
# Archivo actualizado: labels\imagen188.txt
# Archivo actualizado: labels\imagen189.txt
# Archivo actualizado: labels\imagen19.txt
# Archivo actualizado: labels\imagen190.txt
# Archivo actualizado: labels\imagen191.txt
# Archivo actualizado: labels\imagen192.txt
# Archivo actualizado: labels\imagen193.txt
# Archivo actualizado: labels\imagen194.txt
# Archivo actualizado: labels\imagen195.txt
# Archivo actualizado: labels\imagen196.txt
# Archivo actualizado: labels\imagen197.txt
# Archivo actualizado: labels\imagen198.txt
# Archivo actualizado: labels\imagen199.txt
# Archivo actualizado: labels\imagen2.txt
# Archivo actualizado: labels\imagen20.txt
# Archivo actualizado: labels\imagen200.txt
# Archivo actualizado: labels\imagen201.txt
# Archivo actualizado: labels\imagen202.txt
# Archivo actualizado: labels\imagen203.txt
# Archivo actualizado: labels\imagen204.txt
# Archivo actualizado: labels\imagen205.txt
# Archivo actualizado: labels\imagen206.txt
# Archivo actualizado: labels\imagen207.txt
# Archivo actualizado: labels\imagen208.txt
# Archivo actualizado: labels\imagen209.txt
# Archivo actualizado: labels\imagen21.txt
# Archivo actualizado: labels\imagen210.txt
# Archivo actualizado: labels\imagen211.txt
# Archivo actualizado: labels\imagen212.txt
# Archivo actualizado: labels\imagen213.txt
# Archivo actualizado: labels\imagen214.txt
# Archivo actualizado: labels\imagen215.txt
# Archivo actualizado: labels\imagen216.txt
# Archivo actualizado: labels\imagen217.txt
# Archivo actualizado: labels\imagen218.txt
# Archivo actualizado: labels\imagen219.txt
# Archivo actualizado: labels\imagen22.txt
# Archivo actualizado: labels\imagen220.txt
# Archivo actualizado: labels\imagen221.txt
# Archivo actualizado: labels\imagen222.txt
# Archivo actualizado: labels\imagen223.txt
# Archivo actualizado: labels\imagen224.txt
# Archivo actualizado: labels\imagen225.txt
# Archivo actualizado: labels\imagen226.txt
# Archivo actualizado: labels\imagen227.txt
# Archivo actualizado: labels\imagen228.txt
# Archivo actualizado: labels\imagen229.txt
# Archivo actualizado: labels\imagen23.txt
# Archivo actualizado: labels\imagen230.txt
# Archivo actualizado: labels\imagen231.txt
# Archivo actualizado: labels\imagen232.txt
# Archivo actualizado: labels\imagen233.txt
# Archivo actualizado: labels\imagen234.txt
# Archivo actualizado: labels\imagen235.txt
# Archivo actualizado: labels\imagen236.txt
# Archivo actualizado: labels\imagen237.txt
# Archivo actualizado: labels\imagen238.txt
# Archivo actualizado: labels\imagen239.txt
# Archivo actualizado: labels\imagen24.txt
# Archivo actualizado: labels\imagen240.txt
# Archivo actualizado: labels\imagen241.txt
# Archivo actualizado: labels\imagen242.txt
# Archivo actualizado: labels\imagen243.txt
# Archivo actualizado: labels\imagen244.txt
# Archivo actualizado: labels\imagen245.txt
# Archivo actualizado: labels\imagen246.txt
# Archivo actualizado: labels\imagen247.txt
# Archivo actualizado: labels\imagen248.txt
# Archivo actualizado: labels\imagen249.txt
# Archivo actualizado: labels\imagen25.txt
# Archivo actualizado: labels\imagen250.txt
# Archivo actualizado: labels\imagen251.txt
# Archivo actualizado: labels\imagen252.txt
# Archivo actualizado: labels\imagen253.txt
# Archivo actualizado: labels\imagen254.txt
# Archivo actualizado: labels\imagen255.txt
# Archivo actualizado: labels\imagen256.txt
# Archivo actualizado: labels\imagen257.txt
# Archivo actualizado: labels\imagen258.txt
# Archivo actualizado: labels\imagen259.txt
# Archivo actualizado: labels\imagen26.txt
# Archivo actualizado: labels\imagen260.txt
# Archivo actualizado: labels\imagen261.txt
# Archivo actualizado: labels\imagen262.txt
# Archivo actualizado: labels\imagen263.txt
# Archivo actualizado: labels\imagen264.txt
# Archivo actualizado: labels\imagen265.txt
# Archivo actualizado: labels\imagen266.txt
# Archivo actualizado: labels\imagen267.txt
# Archivo actualizado: labels\imagen268.txt
# Archivo actualizado: labels\imagen269.txt
# Archivo actualizado: labels\imagen27.txt
# Archivo actualizado: labels\imagen270.txt
# Archivo actualizado: labels\imagen271.txt
# Archivo actualizado: labels\imagen272.txt
# Archivo actualizado: labels\imagen273.txt
# Archivo actualizado: labels\imagen274.txt
# Archivo actualizado: labels\imagen275.txt
# Archivo actualizado: labels\imagen276.txt
# Archivo actualizado: labels\imagen277.txt
# Archivo actualizado: labels\imagen278.txt
# Archivo actualizado: labels\imagen279.txt
# Archivo actualizado: labels\imagen28.txt
# Archivo actualizado: labels\imagen280.txt
# Archivo actualizado: labels\imagen281.txt
# Archivo actualizado: labels\imagen282.txt
# Archivo actualizado: labels\imagen283.txt
# Archivo actualizado: labels\imagen284.txt
# Archivo actualizado: labels\imagen285.txt
# Archivo actualizado: labels\imagen286.txt
# Archivo actualizado: labels\imagen287.txt
# Archivo actualizado: labels\imagen288.txt
# Archivo actualizado: labels\imagen289.txt
# Archivo actualizado: labels\imagen29.txt
# Archivo actualizado: labels\imagen290.txt
# Archivo actualizado: labels\imagen291.txt
# Archivo actualizado: labels\imagen292.txt
# Archivo actualizado: labels\imagen293.txt
# Archivo actualizado: labels\imagen294.txt
# Archivo actualizado: labels\imagen295.txt
# Archivo actualizado: labels\imagen296.txt
# Archivo actualizado: labels\imagen297.txt
# Archivo actualizado: labels\imagen298.txt
# Archivo actualizado: labels\imagen299.txt
# Archivo actualizado: labels\imagen3.txt
# Archivo actualizado: labels\imagen30.txt
# Archivo actualizado: labels\imagen300.txt
# Archivo actualizado: labels\imagen301.txt
# Archivo actualizado: labels\imagen302.txt
# Archivo actualizado: labels\imagen303.txt
# Archivo actualizado: labels\imagen304.txt
# Archivo actualizado: labels\imagen305.txt
# Archivo actualizado: labels\imagen306.txt
# Archivo actualizado: labels\imagen307.txt
# Archivo actualizado: labels\imagen308.txt
# Archivo actualizado: labels\imagen309.txt
# Archivo actualizado: labels\imagen31.txt
# Archivo actualizado: labels\imagen310.txt
# Archivo actualizado: labels\imagen311.txt
# Archivo actualizado: labels\imagen312.txt
# Archivo actualizado: labels\imagen313.txt
# Archivo actualizado: labels\imagen314.txt
# Archivo actualizado: labels\imagen315.txt
# Archivo actualizado: labels\imagen316.txt
# Archivo actualizado: labels\imagen317.txt
# Archivo actualizado: labels\imagen318.txt
# Archivo actualizado: labels\imagen319.txt
# Archivo actualizado: labels\imagen32.txt
# Archivo actualizado: labels\imagen320.txt
# Archivo actualizado: labels\imagen321.txt
# Archivo actualizado: labels\imagen322.txt
# Archivo actualizado: labels\imagen323.txt
# Archivo actualizado: labels\imagen324.txt
# Archivo actualizado: labels\imagen325.txt
# Archivo actualizado: labels\imagen326.txt
# Archivo actualizado: labels\imagen327.txt
# Archivo actualizado: labels\imagen328.txt
# Archivo actualizado: labels\imagen329.txt
# Archivo actualizado: labels\imagen33.txt
# Archivo actualizado: labels\imagen330.txt
# Archivo actualizado: labels\imagen331.txt
# Archivo actualizado: labels\imagen332.txt
# Archivo actualizado: labels\imagen333.txt
# Archivo actualizado: labels\imagen334.txt
# Archivo actualizado: labels\imagen335.txt
# Archivo actualizado: labels\imagen336.txt
# Archivo actualizado: labels\imagen337.txt
# Archivo actualizado: labels\imagen338.txt
# Archivo actualizado: labels\imagen339.txt
# Archivo actualizado: labels\imagen34.txt
# Archivo actualizado: labels\imagen340.txt
# Archivo actualizado: labels\imagen341.txt
# Archivo actualizado: labels\imagen342.txt
# Archivo actualizado: labels\imagen343.txt
# Archivo actualizado: labels\imagen344.txt
# Archivo actualizado: labels\imagen345.txt
# Archivo actualizado: labels\imagen346.txt
# Archivo actualizado: labels\imagen347.txt
# Archivo actualizado: labels\imagen348.txt
# Archivo actualizado: labels\imagen349.txt
# Archivo actualizado: labels\imagen35.txt
# Archivo actualizado: labels\imagen350.txt
# Archivo actualizado: labels\imagen351.txt
# Archivo actualizado: labels\imagen352.txt
# Archivo actualizado: labels\imagen353.txt
# Archivo actualizado: labels\imagen354.txt
# Archivo actualizado: labels\imagen355.txt
# Archivo actualizado: labels\imagen356.txt
# Archivo actualizado: labels\imagen357.txt
# Archivo actualizado: labels\imagen358.txt
# Archivo actualizado: labels\imagen359.txt
# Archivo actualizado: labels\imagen36.txt
# Archivo actualizado: labels\imagen360.txt
# Archivo actualizado: labels\imagen361.txt
# Archivo actualizado: labels\imagen362.txt
# Archivo actualizado: labels\imagen363.txt
# Archivo actualizado: labels\imagen364.txt
# Archivo actualizado: labels\imagen365.txt
# Archivo actualizado: labels\imagen366.txt
# Archivo actualizado: labels\imagen367.txt
# Archivo actualizado: labels\imagen368.txt
# Archivo actualizado: labels\imagen369.txt
# Archivo actualizado: labels\imagen37.txt
# Archivo actualizado: labels\imagen370.txt
# Archivo actualizado: labels\imagen371.txt
# Archivo actualizado: labels\imagen372.txt
# Archivo actualizado: labels\imagen373.txt
# Archivo actualizado: labels\imagen374.txt
# Archivo actualizado: labels\imagen375.txt
# Archivo actualizado: labels\imagen376.txt
# Archivo actualizado: labels\imagen377.txt
# Archivo actualizado: labels\imagen378.txt
# Archivo actualizado: labels\imagen379.txt
# Archivo actualizado: labels\imagen38.txt
# Archivo actualizado: labels\imagen380.txt
# Archivo actualizado: labels\imagen381.txt
# Archivo actualizado: labels\imagen382.txt
# Archivo actualizado: labels\imagen383.txt
# Archivo actualizado: labels\imagen384.txt
# Archivo actualizado: labels\imagen385.txt
# Archivo actualizado: labels\imagen386.txt
# Archivo actualizado: labels\imagen387.txt
# Archivo actualizado: labels\imagen388.txt
# Archivo actualizado: labels\imagen389.txt
# Archivo actualizado: labels\imagen39.txt
# Archivo actualizado: labels\imagen390.txt
# Archivo actualizado: labels\imagen391.txt
# Archivo actualizado: labels\imagen392.txt
# Archivo actualizado: labels\imagen393.txt
# Archivo actualizado: labels\imagen394.txt
# Archivo actualizado: labels\imagen395.txt
# Archivo actualizado: labels\imagen396.txt
# Archivo actualizado: labels\imagen397.txt
# Archivo actualizado: labels\imagen398.txt
# Archivo actualizado: labels\imagen399.txt
# Archivo actualizado: labels\imagen4.txt
# Archivo actualizado: labels\imagen40.txt
# Archivo actualizado: labels\imagen400.txt
# Archivo actualizado: labels\imagen401.txt
# Archivo actualizado: labels\imagen402.txt
# Archivo actualizado: labels\imagen403.txt
# Archivo actualizado: labels\imagen404.txt
# Archivo actualizado: labels\imagen405.txt
# Archivo actualizado: labels\imagen406.txt
# Archivo actualizado: labels\imagen407.txt
# Archivo actualizado: labels\imagen408.txt
# Archivo actualizado: labels\imagen409.txt
# Archivo actualizado: labels\imagen41.txt
# Archivo actualizado: labels\imagen410.txt
# Archivo actualizado: labels\imagen411.txt
# Archivo actualizado: labels\imagen412.txt
# Archivo actualizado: labels\imagen413.txt
# Archivo actualizado: labels\imagen414.txt
# Archivo actualizado: labels\imagen415.txt
# Archivo actualizado: labels\imagen416.txt
# Archivo actualizado: labels\imagen417.txt
# Archivo actualizado: labels\imagen418.txt
# Archivo actualizado: labels\imagen419.txt
# Archivo actualizado: labels\imagen42.txt
# Archivo actualizado: labels\imagen420.txt
# Archivo actualizado: labels\imagen421.txt
# Archivo actualizado: labels\imagen422.txt
# Archivo actualizado: labels\imagen423.txt
# Archivo actualizado: labels\imagen424.txt
# Archivo actualizado: labels\imagen425.txt
# Archivo actualizado: labels\imagen426.txt
# Archivo actualizado: labels\imagen427.txt
# Archivo actualizado: labels\imagen428.txt
# Archivo actualizado: labels\imagen429.txt
# Archivo actualizado: labels\imagen43.txt
# Archivo actualizado: labels\imagen430.txt
# Archivo actualizado: labels\imagen431.txt
# Archivo actualizado: labels\imagen432.txt
# Archivo actualizado: labels\imagen433.txt
# Archivo actualizado: labels\imagen434.txt
# Archivo actualizado: labels\imagen435.txt
# Archivo actualizado: labels\imagen436.txt
# Archivo actualizado: labels\imagen437.txt
# Archivo actualizado: labels\imagen438.txt
# Archivo actualizado: labels\imagen439.txt
# Archivo actualizado: labels\imagen44.txt
# Archivo actualizado: labels\imagen440.txt
# Archivo actualizado: labels\imagen441.txt
# Archivo actualizado: labels\imagen442.txt
# Archivo actualizado: labels\imagen443.txt
# Archivo actualizado: labels\imagen444.txt
# Archivo actualizado: labels\imagen445.txt
# Archivo actualizado: labels\imagen446.txt
# Archivo actualizado: labels\imagen447.txt
# Archivo actualizado: labels\imagen448.txt
# Archivo actualizado: labels\imagen449.txt
# Archivo actualizado: labels\imagen45.txt
# Archivo actualizado: labels\imagen450.txt
# Archivo actualizado: labels\imagen451.txt
# Archivo actualizado: labels\imagen452.txt
# Archivo actualizado: labels\imagen453.txt
# Archivo actualizado: labels\imagen454.txt
# Archivo actualizado: labels\imagen455.txt
# Archivo actualizado: labels\imagen456.txt
# Archivo actualizado: labels\imagen457.txt
# Archivo actualizado: labels\imagen458.txt
# Archivo actualizado: labels\imagen459.txt
# Archivo actualizado: labels\imagen46.txt
# Archivo actualizado: labels\imagen460.txt
# Archivo actualizado: labels\imagen461.txt
# Archivo actualizado: labels\imagen462.txt
# Archivo actualizado: labels\imagen463.txt
# Archivo actualizado: labels\imagen464.txt
# Archivo actualizado: labels\imagen465.txt
# Archivo actualizado: labels\imagen466.txt
# Archivo actualizado: labels\imagen467.txt
# Archivo actualizado: labels\imagen468.txt
# Archivo actualizado: labels\imagen469.txt
# Archivo actualizado: labels\imagen47.txt
# Archivo actualizado: labels\imagen470.txt
# Archivo actualizado: labels\imagen471.txt
# Archivo actualizado: labels\imagen472.txt
# Archivo actualizado: labels\imagen473.txt
# Archivo actualizado: labels\imagen474.txt
# Archivo actualizado: labels\imagen475.txt
# Archivo actualizado: labels\imagen476.txt
# Archivo actualizado: labels\imagen477.txt
# Archivo actualizado: labels\imagen478.txt
# Archivo actualizado: labels\imagen479.txt
# Archivo actualizado: labels\imagen48.txt
# Archivo actualizado: labels\imagen480.txt
# Archivo actualizado: labels\imagen481.txt
# Archivo actualizado: labels\imagen482.txt
# Archivo actualizado: labels\imagen483.txt
# Archivo actualizado: labels\imagen484.txt
# Archivo actualizado: labels\imagen485.txt
# Archivo actualizado: labels\imagen486.txt
# Archivo actualizado: labels\imagen487.txt
# Archivo actualizado: labels\imagen488.txt
# Archivo actualizado: labels\imagen489.txt
# Archivo actualizado: labels\imagen49.txt
# Archivo actualizado: labels\imagen490.txt
# Archivo actualizado: labels\imagen491.txt
# Archivo actualizado: labels\imagen492.txt
# Archivo actualizado: labels\imagen493.txt
# Archivo actualizado: labels\imagen494.txt
# Archivo actualizado: labels\imagen495.txt
# Archivo actualizado: labels\imagen496.txt
# Archivo actualizado: labels\imagen497.txt
# Archivo actualizado: labels\imagen498.txt
# Archivo actualizado: labels\imagen499.txt
# Archivo actualizado: labels\imagen5.txt
# Archivo actualizado: labels\imagen50.txt
# Archivo actualizado: labels\imagen500.txt
# Archivo actualizado: labels\imagen501.txt
# Archivo actualizado: labels\imagen502.txt
# Archivo actualizado: labels\imagen503.txt
# Archivo actualizado: labels\imagen504.txt
# Archivo actualizado: labels\imagen505.txt
# Archivo actualizado: labels\imagen506.txt
# Archivo actualizado: labels\imagen507.txt
# Archivo actualizado: labels\imagen508.txt
# Archivo actualizado: labels\imagen509.txt
# Archivo actualizado: labels\imagen51.txt
# Archivo actualizado: labels\imagen510.txt
# Archivo actualizado: labels\imagen511.txt
# Archivo actualizado: labels\imagen512.txt
# Archivo actualizado: labels\imagen513.txt
# Archivo actualizado: labels\imagen514.txt
# Archivo actualizado: labels\imagen515.txt
# Archivo actualizado: labels\imagen516.txt
# Archivo actualizado: labels\imagen517.txt
# Archivo actualizado: labels\imagen518.txt
# Archivo actualizado: labels\imagen519.txt
# Archivo actualizado: labels\imagen52.txt
# Archivo actualizado: labels\imagen520.txt
# Archivo actualizado: labels\imagen521.txt
# Archivo actualizado: labels\imagen522.txt
# Archivo actualizado: labels\imagen523.txt
# Archivo actualizado: labels\imagen524.txt
# Archivo actualizado: labels\imagen525.txt
# Archivo actualizado: labels\imagen526.txt
# Archivo actualizado: labels\imagen527.txt
# Archivo actualizado: labels\imagen528.txt
# Archivo actualizado: labels\imagen529.txt
# Archivo actualizado: labels\imagen53.txt
# Archivo actualizado: labels\imagen530.txt
# Archivo actualizado: labels\imagen531.txt
# Archivo actualizado: labels\imagen532.txt
# Archivo actualizado: labels\imagen533.txt
# Archivo actualizado: labels\imagen534.txt
# Archivo actualizado: labels\imagen535.txt
# Archivo actualizado: labels\imagen536.txt
# Archivo actualizado: labels\imagen537.txt
# Archivo actualizado: labels\imagen538.txt
# Archivo actualizado: labels\imagen539.txt
# Archivo actualizado: labels\imagen54.txt
# Archivo actualizado: labels\imagen540.txt
# Archivo actualizado: labels\imagen541.txt
# Archivo actualizado: labels\imagen542.txt
# Archivo actualizado: labels\imagen543.txt
# Archivo actualizado: labels\imagen544.txt
# Archivo actualizado: labels\imagen545.txt
# Archivo actualizado: labels\imagen546.txt
# Archivo actualizado: labels\imagen547.txt
# Archivo actualizado: labels\imagen548.txt
# Archivo actualizado: labels\imagen549.txt
# Archivo actualizado: labels\imagen55.txt
# Archivo actualizado: labels\imagen550.txt
# Archivo actualizado: labels\imagen551.txt
# Archivo actualizado: labels\imagen552.txt
# Archivo actualizado: labels\imagen553.txt
# Archivo actualizado: labels\imagen554.txt
# Archivo actualizado: labels\imagen555.txt
# Archivo actualizado: labels\imagen556.txt
# Archivo actualizado: labels\imagen557.txt
# Archivo actualizado: labels\imagen558.txt
# Archivo actualizado: labels\imagen559.txt
# Archivo actualizado: labels\imagen56.txt
# Archivo actualizado: labels\imagen560.txt
# Archivo actualizado: labels\imagen561.txt
# Archivo actualizado: labels\imagen562.txt
# Archivo actualizado: labels\imagen563.txt
# Archivo actualizado: labels\imagen564.txt
# Archivo actualizado: labels\imagen565.txt
# Archivo actualizado: labels\imagen566.txt
# Archivo actualizado: labels\imagen567.txt
# Archivo actualizado: labels\imagen568.txt
# Archivo actualizado: labels\imagen569.txt
# Archivo actualizado: labels\imagen57.txt
# Archivo actualizado: labels\imagen570.txt
# Archivo actualizado: labels\imagen571.txt
# Archivo actualizado: labels\imagen572.txt
# Archivo actualizado: labels\imagen573.txt
# Archivo actualizado: labels\imagen574.txt
# Archivo actualizado: labels\imagen575.txt
# Archivo actualizado: labels\imagen576.txt
# Archivo actualizado: labels\imagen577.txt
# Archivo actualizado: labels\imagen578.txt
# Archivo actualizado: labels\imagen579.txt
# Archivo actualizado: labels\imagen58.txt
# Archivo actualizado: labels\imagen580.txt
# Archivo actualizado: labels\imagen581.txt
# Archivo actualizado: labels\imagen582.txt
# Archivo actualizado: labels\imagen583.txt
# Archivo actualizado: labels\imagen584.txt
# Archivo actualizado: labels\imagen585.txt
# Archivo actualizado: labels\imagen586.txt
# Archivo actualizado: labels\imagen587.txt
# Archivo actualizado: labels\imagen588.txt
# Archivo actualizado: labels\imagen589.txt
# Archivo actualizado: labels\imagen59.txt
# Archivo actualizado: labels\imagen590.txt
# Archivo actualizado: labels\imagen591.txt
# Archivo actualizado: labels\imagen592.txt
# Archivo actualizado: labels\imagen593.txt
# Archivo actualizado: labels\imagen594.txt
# Archivo actualizado: labels\imagen595.txt
# Archivo actualizado: labels\imagen596.txt
# Archivo actualizado: labels\imagen597.txt
# Archivo actualizado: labels\imagen598.txt
# Archivo actualizado: labels\imagen599.txt
# Archivo actualizado: labels\imagen6.txt
# Archivo actualizado: labels\imagen60.txt
# Archivo actualizado: labels\imagen600.txt
# Archivo actualizado: labels\imagen601.txt
# Archivo actualizado: labels\imagen602.txt
# Archivo actualizado: labels\imagen603.txt
# Archivo actualizado: labels\imagen604.txt
# Archivo actualizado: labels\imagen605.txt
# Archivo actualizado: labels\imagen606.txt
# Archivo actualizado: labels\imagen607.txt
# Archivo actualizado: labels\imagen608.txt
# Archivo actualizado: labels\imagen609.txt
# Archivo actualizado: labels\imagen61.txt
# Archivo actualizado: labels\imagen610.txt
# Archivo actualizado: labels\imagen611.txt
# Archivo actualizado: labels\imagen612.txt
# Archivo actualizado: labels\imagen613.txt
# Archivo actualizado: labels\imagen614.txt
# Archivo actualizado: labels\imagen615.txt
# Archivo actualizado: labels\imagen616.txt
# Archivo actualizado: labels\imagen617.txt
# Archivo actualizado: labels\imagen618.txt
# Archivo actualizado: labels\imagen619.txt
# Archivo actualizado: labels\imagen62.txt
# Archivo actualizado: labels\imagen620.txt
# Archivo actualizado: labels\imagen621.txt
# Archivo actualizado: labels\imagen622.txt
# Archivo actualizado: labels\imagen623.txt
# Archivo actualizado: labels\imagen624.txt
# Archivo actualizado: labels\imagen625.txt
# Archivo actualizado: labels\imagen626.txt
# Archivo actualizado: labels\imagen627.txt
# Archivo actualizado: labels\imagen628.txt
# Archivo actualizado: labels\imagen629.txt
# Archivo actualizado: labels\imagen63.txt
# Archivo actualizado: labels\imagen630.txt
# Archivo actualizado: labels\imagen631.txt
# Archivo actualizado: labels\imagen632.txt
# Archivo actualizado: labels\imagen633.txt
# Archivo actualizado: labels\imagen634.txt
# Archivo actualizado: labels\imagen635.txt
# Archivo actualizado: labels\imagen636.txt
# Archivo actualizado: labels\imagen637.txt
# Archivo actualizado: labels\imagen638.txt
# Archivo actualizado: labels\imagen639.txt
# Archivo actualizado: labels\imagen64.txt
# Archivo actualizado: labels\imagen640.txt
# Archivo actualizado: labels\imagen641.txt
# Archivo actualizado: labels\imagen642.txt
# Archivo actualizado: labels\imagen643.txt
# Archivo actualizado: labels\imagen644.txt
# Archivo actualizado: labels\imagen645.txt
# Archivo actualizado: labels\imagen646.txt
# Archivo actualizado: labels\imagen647.txt
# Archivo actualizado: labels\imagen648.txt
# Archivo actualizado: labels\imagen649.txt
# Archivo actualizado: labels\imagen65.txt
# Archivo actualizado: labels\imagen650.txt
# Archivo actualizado: labels\imagen651.txt
# Archivo actualizado: labels\imagen652.txt
# Archivo actualizado: labels\imagen653.txt
# Archivo actualizado: labels\imagen654.txt
# Archivo actualizado: labels\imagen655.txt
# Archivo actualizado: labels\imagen656.txt
# Archivo actualizado: labels\imagen657.txt
# Archivo actualizado: labels\imagen658.txt
# Archivo actualizado: labels\imagen659.txt
# Archivo actualizado: labels\imagen66.txt
# Archivo actualizado: labels\imagen660.txt
# Archivo actualizado: labels\imagen661.txt
# Archivo actualizado: labels\imagen662.txt
# Archivo actualizado: labels\imagen663.txt
# Archivo actualizado: labels\imagen664.txt
# Archivo actualizado: labels\imagen665.txt
# Archivo actualizado: labels\imagen666.txt
# Archivo actualizado: labels\imagen667.txt
# Archivo actualizado: labels\imagen668.txt
# Archivo actualizado: labels\imagen669.txt
# Archivo actualizado: labels\imagen67.txt
# Archivo actualizado: labels\imagen670.txt
# Archivo actualizado: labels\imagen671.txt
# Archivo actualizado: labels\imagen672.txt
# Archivo actualizado: labels\imagen673.txt
# Archivo actualizado: labels\imagen674.txt
# Archivo actualizado: labels\imagen675.txt
# Archivo actualizado: labels\imagen676.txt
# Archivo actualizado: labels\imagen677.txt
# Archivo actualizado: labels\imagen678.txt
# Archivo actualizado: labels\imagen679.txt
# Archivo actualizado: labels\imagen68.txt
# Archivo actualizado: labels\imagen680.txt
# Archivo actualizado: labels\imagen681.txt
# Archivo actualizado: labels\imagen682.txt
# Archivo actualizado: labels\imagen683.txt
# Archivo actualizado: labels\imagen684.txt
# Archivo actualizado: labels\imagen685.txt
# Archivo actualizado: labels\imagen686.txt
# Archivo actualizado: labels\imagen687.txt
# Archivo actualizado: labels\imagen688.txt
# Archivo actualizado: labels\imagen689.txt
# Archivo actualizado: labels\imagen69.txt
# Archivo actualizado: labels\imagen690.txt
# Archivo actualizado: labels\imagen691.txt
# Archivo actualizado: labels\imagen692.txt
# Archivo actualizado: labels\imagen693.txt
# Archivo actualizado: labels\imagen694.txt
# Archivo actualizado: labels\imagen695.txt
# Archivo actualizado: labels\imagen696.txt
# Archivo actualizado: labels\imagen697.txt
# Archivo actualizado: labels\imagen698.txt
# Archivo actualizado: labels\imagen699.txt
# Archivo actualizado: labels\imagen7.txt
# Archivo actualizado: labels\imagen70.txt
# Archivo actualizado: labels\imagen700.txt
# Archivo actualizado: labels\imagen701.txt
# Archivo actualizado: labels\imagen702.txt
# Archivo actualizado: labels\imagen703.txt
# Archivo actualizado: labels\imagen704.txt
# Archivo actualizado: labels\imagen705.txt
# Archivo actualizado: labels\imagen706.txt
# Archivo actualizado: labels\imagen707.txt
# Archivo actualizado: labels\imagen708.txt
# Archivo actualizado: labels\imagen709.txt
# Archivo actualizado: labels\imagen71.txt
# Archivo actualizado: labels\imagen710.txt
# Archivo actualizado: labels\imagen711.txt
# Archivo actualizado: labels\imagen712.txt
# Archivo actualizado: labels\imagen713.txt
# Archivo actualizado: labels\imagen714.txt
# Archivo actualizado: labels\imagen715.txt
# Archivo actualizado: labels\imagen716.txt
# Archivo actualizado: labels\imagen717.txt
# Archivo actualizado: labels\imagen718.txt
# Archivo actualizado: labels\imagen719.txt
# Archivo actualizado: labels\imagen72.txt
# Archivo actualizado: labels\imagen720.txt
# Archivo actualizado: labels\imagen721.txt
# Archivo actualizado: labels\imagen722.txt
# Archivo actualizado: labels\imagen723.txt
# Archivo actualizado: labels\imagen724.txt
# Archivo actualizado: labels\imagen725.txt
# Archivo actualizado: labels\imagen726.txt
# Archivo actualizado: labels\imagen727.txt
# Archivo actualizado: labels\imagen728.txt
# Archivo actualizado: labels\imagen729.txt
# Archivo actualizado: labels\imagen73.txt
# Archivo actualizado: labels\imagen730.txt
# Archivo actualizado: labels\imagen731.txt
# Archivo actualizado: labels\imagen732.txt
# Archivo actualizado: labels\imagen733.txt
# Archivo actualizado: labels\imagen734.txt
# Archivo actualizado: labels\imagen735.txt
# Archivo actualizado: labels\imagen736.txt
# Archivo actualizado: labels\imagen737.txt
# Archivo actualizado: labels\imagen738.txt
# Archivo actualizado: labels\imagen739.txt
# Archivo actualizado: labels\imagen74.txt
# Archivo actualizado: labels\imagen740.txt
# Archivo actualizado: labels\imagen741.txt
# Archivo actualizado: labels\imagen742.txt
# Archivo actualizado: labels\imagen743.txt
# Archivo actualizado: labels\imagen744.txt
# Archivo actualizado: labels\imagen745.txt
# Archivo actualizado: labels\imagen746.txt
# Archivo actualizado: labels\imagen747.txt
# Archivo actualizado: labels\imagen748.txt
# Archivo actualizado: labels\imagen749.txt
# Archivo actualizado: labels\imagen75.txt
# Archivo actualizado: labels\imagen750.txt
# Archivo actualizado: labels\imagen751.txt
# Archivo actualizado: labels\imagen752.txt
# Archivo actualizado: labels\imagen753.txt
# Archivo actualizado: labels\imagen754.txt
# Archivo actualizado: labels\imagen755.txt
# Archivo actualizado: labels\imagen756.txt
# Archivo actualizado: labels\imagen757.txt
# Archivo actualizado: labels\imagen758.txt
# Archivo actualizado: labels\imagen759.txt
# Archivo actualizado: labels\imagen76.txt
# Archivo actualizado: labels\imagen760.txt
# Archivo actualizado: labels\imagen761.txt
# Archivo actualizado: labels\imagen762.txt
# Archivo actualizado: labels\imagen763.txt
# Archivo actualizado: labels\imagen764.txt
# Archivo actualizado: labels\imagen765.txt
# Archivo actualizado: labels\imagen766.txt
# Archivo actualizado: labels\imagen767.txt
# Archivo actualizado: labels\imagen768.txt
# Archivo actualizado: labels\imagen769.txt
# Archivo actualizado: labels\imagen77.txt
# Archivo actualizado: labels\imagen770.txt
# Archivo actualizado: labels\imagen771.txt
# Archivo actualizado: labels\imagen772.txt
# Archivo actualizado: labels\imagen773.txt
# Archivo actualizado: labels\imagen774.txt
# Archivo actualizado: labels\imagen775.txt
# Archivo actualizado: labels\imagen776.txt
# Archivo actualizado: labels\imagen777.txt
# Archivo actualizado: labels\imagen778.txt
# Archivo actualizado: labels\imagen779.txt
# Archivo actualizado: labels\imagen78.txt
# Archivo actualizado: labels\imagen780.txt
# Archivo actualizado: labels\imagen781.txt
# Archivo actualizado: labels\imagen782.txt
# Archivo actualizado: labels\imagen783.txt
# Archivo actualizado: labels\imagen784.txt
# Archivo actualizado: labels\imagen785.txt
# Archivo actualizado: labels\imagen786.txt
# Archivo actualizado: labels\imagen787.txt
# Archivo actualizado: labels\imagen788.txt
# Archivo actualizado: labels\imagen789.txt
# Archivo actualizado: labels\imagen79.txt
# Archivo actualizado: labels\imagen790.txt
# Archivo actualizado: labels\imagen791.txt
# Archivo actualizado: labels\imagen792.txt
# Archivo actualizado: labels\imagen793.txt
# Archivo actualizado: labels\imagen794.txt
# Archivo actualizado: labels\imagen795.txt
# Archivo actualizado: labels\imagen796.txt
# Archivo actualizado: labels\imagen797.txt
# Archivo actualizado: labels\imagen798.txt
# Archivo actualizado: labels\imagen799.txt
# Archivo actualizado: labels\imagen8.txt
# Archivo actualizado: labels\imagen80.txt
# Archivo actualizado: labels\imagen800.txt
# Archivo actualizado: labels\imagen801.txt
# Archivo actualizado: labels\imagen802.txt
# Archivo actualizado: labels\imagen803.txt
# Archivo actualizado: labels\imagen804.txt
# Archivo actualizado: labels\imagen805.txt
# Archivo actualizado: labels\imagen806.txt
# Archivo actualizado: labels\imagen807.txt
# Archivo actualizado: labels\imagen808.txt
# Archivo actualizado: labels\imagen809.txt
# Archivo actualizado: labels\imagen81.txt
# Archivo actualizado: labels\imagen810.txt
# Archivo actualizado: labels\imagen811.txt
# Archivo actualizado: labels\imagen812.txt
# Archivo actualizado: labels\imagen813.txt
# Archivo actualizado: labels\imagen814.txt
# Archivo actualizado: labels\imagen815.txt
# Archivo actualizado: labels\imagen816.txt
# Archivo actualizado: labels\imagen817.txt
# Archivo actualizado: labels\imagen818.txt
# Archivo actualizado: labels\imagen819.txt
# Archivo actualizado: labels\imagen82.txt
# Archivo actualizado: labels\imagen820.txt
# Archivo actualizado: labels\imagen821.txt
# Archivo actualizado: labels\imagen822.txt
# Archivo actualizado: labels\imagen823.txt
# Archivo actualizado: labels\imagen824.txt
# Archivo actualizado: labels\imagen825.txt
# Archivo actualizado: labels\imagen826.txt
# Archivo actualizado: labels\imagen827.txt
# Archivo actualizado: labels\imagen828.txt
# Archivo actualizado: labels\imagen829.txt
# Archivo actualizado: labels\imagen83.txt
# Archivo actualizado: labels\imagen830.txt
# Archivo actualizado: labels\imagen831.txt
# Archivo actualizado: labels\imagen832.txt
# Archivo actualizado: labels\imagen833.txt
# Archivo actualizado: labels\imagen834.txt
# Archivo actualizado: labels\imagen835.txt
# Archivo actualizado: labels\imagen836.txt
# Archivo actualizado: labels\imagen837.txt
# Archivo actualizado: labels\imagen838.txt
# Archivo actualizado: labels\imagen839.txt
# Archivo actualizado: labels\imagen84.txt
# Archivo actualizado: labels\imagen840.txt
# Archivo actualizado: labels\imagen841.txt
# Archivo actualizado: labels\imagen842.txt
# Archivo actualizado: labels\imagen843.txt
# Archivo actualizado: labels\imagen844.txt
# Archivo actualizado: labels\imagen845.txt
# Archivo actualizado: labels\imagen846.txt
# Archivo actualizado: labels\imagen847.txt
# Archivo actualizado: labels\imagen848.txt
# Archivo actualizado: labels\imagen849.txt
# Archivo actualizado: labels\imagen85.txt
# Archivo actualizado: labels\imagen850.txt
# Archivo actualizado: labels\imagen851.txt
# Archivo actualizado: labels\imagen852.txt
# Archivo actualizado: labels\imagen853.txt
# Archivo actualizado: labels\imagen854.txt
# Archivo actualizado: labels\imagen855.txt
# Archivo actualizado: labels\imagen856.txt
# Archivo actualizado: labels\imagen857.txt
# Archivo actualizado: labels\imagen858.txt
# Archivo actualizado: labels\imagen859.txt
# Archivo actualizado: labels\imagen86.txt
# Archivo actualizado: labels\imagen860.txt
# Archivo actualizado: labels\imagen861.txt
# Archivo actualizado: labels\imagen862.txt
# Archivo actualizado: labels\imagen863.txt
# Archivo actualizado: labels\imagen864.txt
# Archivo actualizado: labels\imagen865.txt
# Archivo actualizado: labels\imagen866.txt
# Archivo actualizado: labels\imagen867.txt
# Archivo actualizado: labels\imagen868.txt
# Archivo actualizado: labels\imagen869.txt
# Archivo actualizado: labels\imagen87.txt
# Archivo actualizado: labels\imagen870.txt
# Archivo actualizado: labels\imagen871.txt
# Archivo actualizado: labels\imagen872.txt
# Archivo actualizado: labels\imagen873.txt
# Archivo actualizado: labels\imagen874.txt
# Archivo actualizado: labels\imagen875.txt
# Archivo actualizado: labels\imagen876.txt
# Archivo actualizado: labels\imagen877.txt
# Archivo actualizado: labels\imagen878.txt
# Archivo actualizado: labels\imagen879.txt
# Archivo actualizado: labels\imagen88.txt
# Archivo actualizado: labels\imagen880.txt
# Archivo actualizado: labels\imagen881.txt
# Archivo actualizado: labels\imagen882.txt
# Archivo actualizado: labels\imagen883.txt
# Archivo actualizado: labels\imagen884.txt
# Archivo actualizado: labels\imagen885.txt
# Archivo actualizado: labels\imagen886.txt
# Archivo actualizado: labels\imagen887.txt
# Archivo actualizado: labels\imagen888.txt
# Archivo actualizado: labels\imagen889.txt
# Archivo actualizado: labels\imagen89.txt
# Archivo actualizado: labels\imagen890.txt
# Archivo actualizado: labels\imagen891.txt
# Archivo actualizado: labels\imagen892.txt
# Archivo actualizado: labels\imagen893.txt
# Archivo actualizado: labels\imagen894.txt
# Archivo actualizado: labels\imagen895.txt
# Archivo actualizado: labels\imagen896.txt
# Archivo actualizado: labels\imagen897.txt
# Archivo actualizado: labels\imagen898.txt
# Archivo actualizado: labels\imagen899.txt
# Archivo actualizado: labels\imagen9.txt
# Archivo actualizado: labels\imagen90.txt
# Archivo actualizado: labels\imagen900.txt
# Archivo actualizado: labels\imagen901.txt
# Archivo actualizado: labels\imagen902.txt
# Archivo actualizado: labels\imagen903.txt
# Archivo actualizado: labels\imagen904.txt
# Archivo actualizado: labels\imagen905.txt
# Archivo actualizado: labels\imagen906.txt
# Archivo actualizado: labels\imagen907.txt
# Archivo actualizado: labels\imagen908.txt
# Archivo actualizado: labels\imagen909.txt
# Archivo actualizado: labels\imagen91.txt
# Archivo actualizado: labels\imagen910.txt
# Archivo actualizado: labels\imagen911.txt
# Archivo actualizado: labels\imagen912.txt
# Archivo actualizado: labels\imagen913.txt
# Archivo actualizado: labels\imagen914.txt
# Archivo actualizado: labels\imagen915.txt
# Archivo actualizado: labels\imagen916.txt
# Archivo actualizado: labels\imagen917.txt
# Archivo actualizado: labels\imagen918.txt
# Archivo actualizado: labels\imagen919.txt
# Archivo actualizado: labels\imagen92.txt
# Archivo actualizado: labels\imagen920.txt
# Archivo actualizado: labels\imagen921.txt
# Archivo actualizado: labels\imagen922.txt
# Archivo actualizado: labels\imagen923.txt
# Archivo actualizado: labels\imagen924.txt
# Archivo actualizado: labels\imagen925.txt
# Archivo actualizado: labels\imagen926.txt
# Archivo actualizado: labels\imagen927.txt
# Archivo actualizado: labels\imagen928.txt
# Archivo actualizado: labels\imagen929.txt
# Archivo actualizado: labels\imagen93.txt
# Archivo actualizado: labels\imagen930.txt
# Archivo actualizado: labels\imagen931.txt
# Archivo actualizado: labels\imagen932.txt
# Archivo actualizado: labels\imagen933.txt
# Archivo actualizado: labels\imagen934.txt
# Archivo actualizado: labels\imagen935.txt
# Archivo actualizado: labels\imagen936.txt
# Archivo actualizado: labels\imagen937.txt
# Archivo actualizado: labels\imagen938.txt
# Archivo actualizado: labels\imagen939.txt
# Archivo actualizado: labels\imagen94.txt
# Archivo actualizado: labels\imagen940.txt
# Archivo actualizado: labels\imagen941.txt
# Archivo actualizado: labels\imagen942.txt
# Archivo actualizado: labels\imagen943.txt
# Archivo actualizado: labels\imagen944.txt
# Archivo actualizado: labels\imagen945.txt
# Archivo actualizado: labels\imagen946.txt
# Archivo actualizado: labels\imagen947.txt
# Archivo actualizado: labels\imagen948.txt
# Archivo actualizado: labels\imagen949.txt
# Archivo actualizado: labels\imagen95.txt
# Archivo actualizado: labels\imagen950.txt
# Archivo actualizado: labels\imagen951.txt
# Archivo actualizado: labels\imagen952.txt
# Archivo actualizado: labels\imagen953.txt
# Archivo actualizado: labels\imagen954.txt
# Archivo actualizado: labels\imagen955.txt
# Archivo actualizado: labels\imagen956.txt
# Archivo actualizado: labels\imagen957.txt
# Archivo actualizado: labels\imagen958.txt
# Archivo actualizado: labels\imagen959.txt
# Archivo actualizado: labels\imagen96.txt
# Archivo actualizado: labels\imagen960.txt
# Archivo actualizado: labels\imagen961.txt
# Archivo actualizado: labels\imagen962.txt
# Archivo actualizado: labels\imagen963.txt
# Archivo actualizado: labels\imagen964.txt
# Archivo actualizado: labels\imagen965.txt
# Archivo actualizado: labels\imagen966.txt
# Archivo actualizado: labels\imagen967.txt
# Archivo actualizado: labels\imagen968.txt
# Archivo actualizado: labels\imagen969.txt
# Archivo actualizado: labels\imagen97.txt
# Archivo actualizado: labels\imagen970.txt
# Archivo actualizado: labels\imagen971.txt
# Archivo actualizado: labels\imagen972.txt
# Archivo actualizado: labels\imagen973.txt
# Archivo actualizado: labels\imagen974.txt
# Archivo actualizado: labels\imagen975.txt
# Archivo actualizado: labels\imagen976.txt
# Archivo actualizado: labels\imagen977.txt
# Archivo actualizado: labels\imagen978.txt
# Archivo actualizado: labels\imagen979.txt
# Archivo actualizado: labels\imagen98.txt
# Archivo actualizado: labels\imagen980.txt
# Archivo actualizado: labels\imagen981.txt
# Archivo actualizado: labels\imagen982.txt
# Archivo actualizado: labels\imagen983.txt
# Archivo actualizado: labels\imagen984.txt
# Archivo actualizado: labels\imagen985.txt
# Archivo actualizado: labels\imagen986.txt
# Archivo actualizado: labels\imagen987.txt
# Archivo actualizado: labels\imagen988.txt
# Archivo actualizado: labels\imagen989.txt
# Archivo actualizado: labels\imagen99.txt
# Archivo actualizado: labels\imagen990.txt
# Archivo actualizado: labels\imagen991.txt
# Archivo actualizado: labels\imagen992.txt
# Archivo actualizado: labels\imagen993.txt
# Archivo actualizado: labels\imagen994.txt
# Archivo actualizado: labels\imagen995.txt
# Archivo actualizado: labels\imagen996.txt
# Archivo actualizado: labels\imagen997.txt
# Archivo actualizado: labels\imagen998.txt
# Archivo actualizado: labels\imagen999.txt
# Proceso completado: todas las clases se han establecido en '0'.

# %% [markdown]
# ## Cambiar nombres de archivos de imagen y etiquetas a algo mas facil de leer

# %%
import os

image_folder = "images"
label_folder = "labels"

image_files = set()
label_files = set()

# Recorre las imágenes e imprime cada archivo
print("Analizando imágenes...")
for f in os.listdir(image_folder):
    if f.endswith(('.jpg', '.png')):
        print(f"Imagen encontrada: {f}")
        image_files.add(f.rsplit('.', 1)[0])

# Recorre las etiquetas e imprime cada archivo
print("\nAnalizando etiquetas...")
for f in os.listdir(label_folder):
    if f.endswith('.txt'):
        print(f"Etiqueta encontrada: {f}")
        label_files.add(f.rsplit('.', 1)[0])

# Encuentra imágenes sin etiquetas
sin_etiquetas = image_files - label_files
if sin_etiquetas:
    print("\nImágenes sin etiquetas:")
    for img in sin_etiquetas:
        print(f"- {img}.jpg o {img}.png")
else:
    print("\nTodas las imágenes tienen su etiqueta correspondiente.")

# Encuentra etiquetas sin imágenes
sin_imagenes = label_files - image_files
if sin_imagenes:
    print("\nEtiquetas sin imágenes:")
    for lbl in sin_imagenes:
        print(f"- {lbl}.txt")
else:
    print("\nTodas las etiquetas tienen su imagen correspondiente.")

# Renombra las imágenes y sus etiquetas
print("\nRenombrando archivos...")
contador = 1
for img_base in sorted(image_files):
    img_path = None
    for ext in ['.jpg', '.png']:
        posible_path = os.path.join(image_folder, img_base + ext)
        if os.path.exists(posible_path):
            img_path = posible_path
            img_ext = ext
            break

    if not img_path:
        print(f"No se encontró la imagen para {img_base}, se omite.")
        continue

    label_path = os.path.join(label_folder, img_base + '.txt')

    nuevo_nombre = f"imagen{contador}"

    nuevo_img_path = os.path.join(image_folder, nuevo_nombre + img_ext)
    nuevo_label_path = os.path.join(label_folder, nuevo_nombre + '.txt')

    os.rename(img_path, nuevo_img_path)
    print(f"Imagen renombrada: {img_path} -> {nuevo_img_path}")

    if os.path.exists(label_path):
        os.rename(label_path, nuevo_label_path)
        print(f"Etiqueta renombrada: {label_path} -> {nuevo_label_path}")

    contador += 1

print("\nRenombrado completado.")
# Out:
# Analizando imágenes...
# Imagen encontrada: 000043_jpg.rf.b8ced8325aff797b297ae86b903f0338.jpg
# Imagen encontrada: 000076_jpg.rf.1509422cc6b4d74b227cb2638649bd06.jpg
# Imagen encontrada: 000087_jpg.rf.dad4d7e23fbfee8a5636df7fc6dd51fc.jpg
# Imagen encontrada: 000113_jpg.rf.175fcdd4d8e9c1747a63230b908fccde.jpg
# Imagen encontrada: 000186_jpg.rf.16fec0f3ac7db08be441517fbaa4c34d.jpg
# Imagen encontrada: 000188_jpg.rf.71f4729acf89d40ad122d26a4a3c00a3.jpg
# Imagen encontrada: 000209_jpg.rf.fe4a4027bdfe58bc9519ed6542a2342a.jpg
# Imagen encontrada: 000239_jpg.rf.fad8fbe80e181641958f7f96c36041cc.jpg
# Imagen encontrada: 000533_jpg.rf.699ee9b6fee643b86c809ed60235a03e.jpg
# Imagen encontrada: 000620_jpg.rf.ac07e1a159967bac8fdc3525eea65b4a.jpg
# Imagen encontrada: 000709_jpg.rf.f81e7673d30dee2e5157c4a39b815989.jpg
# Imagen encontrada: 000827_jpg.rf.8e6e203f65c99ca7d9eda37587e8561c.jpg
# Imagen encontrada: 000867_jpg.rf.6096e17accf7a09131b9520f5b3cb458.jpg
# Imagen encontrada: 001054_jpg.rf.4a6daa7d946e54a1ffbc0332f842284e.jpg
jpg
# Etiqueta renombrada: labels\teknofest_2021_p-2788-_jpg.rf.df19b5fc4a2415c8e08a744f766d4b0e.txt -> labels\imagen1139.txt
# Imagen renombrada: images\teknofest_2021_p-2894-_jpg.rf.43729d4a1f40bd83f6481fffd85d86c4.jpg -> images\imagen1140.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-2894-_jpg.rf.43729d4a1f40bd83f6481fffd85d86c4.txt -> labels\imagen1140.txt
# Imagen renombrada: images\teknofest_2021_p-29-_jpg.rf.8b53141bac1c2751a73bccebb3af870d.jpg -> images\imagen1141.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-29-_jpg.rf.8b53141bac1c2751a73bccebb3af870d.txt -> labels\imagen1141.txt
# Imagen renombrada: images\teknofest_2021_p-2940-_jpg.rf.eef12151f3112fd050753f7504261f49.jpg -> images\imagen1142.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-2940-_jpg.rf.eef12151f3112fd050753f7504261f49.txt -> labels\imagen1142.txt
# Imagen renombrada: images\teknofest_2021_p-296-_jpg.rf.21dfd1155db77b61470bb5f3ab9b817d.jpg -> images\imagen1143.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-296-_jpg.rf.21dfd1155db77b61470bb5f3ab9b817d.txt -> labels\imagen1143.txt
# Imagen renombrada: images\teknofest_2021_p-2967-_jpg.rf.41a6b139e2a56b3f3ec0b729117faef3.jpg -> images\imagen1144.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-2967-_jpg.rf.41a6b139e2a56b3f3ec0b729117faef3.txt -> labels\imagen1144.txt
# Imagen renombrada: images\teknofest_2021_p-3041-_jpg.rf.280def2c7047649d3cb0a75622f274e2.jpg -> images\imagen1145.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3041-_jpg.rf.280def2c7047649d3cb0a75622f274e2.txt -> labels\imagen1145.txt
# Imagen renombrada: images\teknofest_2021_p-3135-_jpg.rf.86a24158d6c8f2480291665d82c3b71e.jpg -> images\imagen1146.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3135-_jpg.rf.86a24158d6c8f2480291665d82c3b71e.txt -> labels\imagen1146.txt
# Imagen renombrada: images\teknofest_2021_p-3147-_jpg.rf.2e7e3d8346400b32b1a09d2d09f8a53a.jpg -> images\imagen1147.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3147-_jpg.rf.2e7e3d8346400b32b1a09d2d09f8a53a.txt -> labels\imagen1147.txt
# Imagen renombrada: images\teknofest_2021_p-3208-_jpg.rf.4301ebbecbbc18b14a4f07fec3ca3f49.jpg -> images\imagen1148.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3208-_jpg.rf.4301ebbecbbc18b14a4f07fec3ca3f49.txt -> labels\imagen1148.txt
# Imagen renombrada: images\teknofest_2021_p-3224-_jpg.rf.3133e66801c0c20915efdde8965187f0.jpg -> images\imagen1149.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3224-_jpg.rf.3133e66801c0c20915efdde8965187f0.txt -> labels\imagen1149.txt
# Imagen renombrada: images\teknofest_2021_p-3251-_jpg.rf.e155c4d86eafa9d5f0b54917cfbcbcac.jpg -> images\imagen1150.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3251-_jpg.rf.e155c4d86eafa9d5f0b54917cfbcbcac.txt -> labels\imagen1150.txt
# Imagen renombrada: images\teknofest_2021_p-3254-_jpg.rf.e594cfda5f792487f97c6588703810f0.jpg -> images\imagen1151.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3254-_jpg.rf.e594cfda5f792487f97c6588703810f0.txt -> labels\imagen1151.txt
# Imagen renombrada: images\teknofest_2021_p-328-_jpg.rf.5017b44b7e397d93664038f4df11faa1.jpg -> images\imagen1152.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-328-_jpg.rf.5017b44b7e397d93664038f4df11faa1.txt -> labels\imagen1152.txt
# Imagen renombrada: images\teknofest_2021_p-3357-_jpg.rf.3a5e18ec884c948faee9823cbdaa87f6.jpg -> images\imagen1153.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3357-_jpg.rf.3a5e18ec884c948faee9823cbdaa87f6.txt -> labels\imagen1153.txt
# Imagen renombrada: images\teknofest_2021_p-3450-_jpg.rf.5ccf1be5a80dd129d89c1a4b4e891af1.jpg -> images\imagen1154.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3450-_jpg.rf.5ccf1be5a80dd129d89c1a4b4e891af1.txt -> labels\imagen1154.txt
# Imagen renombrada: images\teknofest_2021_p-3493-_jpg.rf.2023709e8e29d278e2ab14762e2a7a7f.jpg -> images\imagen1155.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3493-_jpg.rf.2023709e8e29d278e2ab14762e2a7a7f.txt -> labels\imagen1155.txt
# Imagen renombrada: images\teknofest_2021_p-3537-_jpg.rf.62cc2902c00a8aa7596acc0a571b9a17.jpg -> images\imagen1156.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3537-_jpg.rf.62cc2902c00a8aa7596acc0a571b9a17.txt -> labels\imagen1156.txt
# Imagen renombrada: images\teknofest_2021_p-3645-_jpg.rf.8499b7e1365bbf6c9f4b462d7e53b7b2.jpg -> images\imagen1157.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3645-_jpg.rf.8499b7e1365bbf6c9f4b462d7e53b7b2.txt -> labels\imagen1157.txt
# Imagen renombrada: images\teknofest_2021_p-3686-_jpg.rf.56e2f89b76f975cf78df6484621db920.jpg -> images\imagen1158.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3686-_jpg.rf.56e2f89b76f975cf78df6484621db920.txt -> labels\imagen1158.txt
# Imagen renombrada: images\teknofest_2021_p-3806-_jpg.rf.2bfdf8eeaa6e54b77c5a76dc44ca5b5b.jpg -> images\imagen1159.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3806-_jpg.rf.2bfdf8eeaa6e54b77c5a76dc44ca5b5b.txt -> labels\imagen1159.txt
# Imagen renombrada: images\teknofest_2021_p-3839-_jpg.rf.b778eb9e9662e4be39ba26199ba1f120.jpg -> images\imagen1160.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3839-_jpg.rf.b778eb9e9662e4be39ba26199ba1f120.txt -> labels\imagen1160.txt
# Imagen renombrada: images\teknofest_2021_p-3853-_jpg.rf.6e1988a829759d355a22b6377b9fdbf2.jpg -> images\imagen1161.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3853-_jpg.rf.6e1988a829759d355a22b6377b9fdbf2.txt -> labels\imagen1161.txt
# Imagen renombrada: images\teknofest_2021_p-389-_jpg.rf.54ba5cd7b75b024613a667a349bf4994.jpg -> images\imagen1162.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-389-_jpg.rf.54ba5cd7b75b024613a667a349bf4994.txt -> labels\imagen1162.txt
# Imagen renombrada: images\teknofest_2021_p-3900-_jpg.rf.e4854fa84e0aef6b5f4f3e462ea1e9d0.jpg -> images\imagen1163.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-3900-_jpg.rf.e4854fa84e0aef6b5f4f3e462ea1e9d0.txt -> labels\imagen1163.txt
# Imagen renombrada: images\teknofest_2021_p-4019-_jpg.rf.018ac978d8d483b44dc7ad29a92597f8.jpg -> images\imagen1164.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4019-_jpg.rf.018ac978d8d483b44dc7ad29a92597f8.txt -> labels\imagen1164.txt
# Imagen renombrada: images\teknofest_2021_p-4123-_jpg.rf.5777bfb070078b114d1fd9b08d2fe57e.jpg -> images\imagen1165.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4123-_jpg.rf.5777bfb070078b114d1fd9b08d2fe57e.txt -> labels\imagen1165.txt
# Imagen renombrada: images\teknofest_2021_p-4197-_jpg.rf.1d716de85086c9060ec68d95f911a14b.jpg -> images\imagen1166.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4197-_jpg.rf.1d716de85086c9060ec68d95f911a14b.txt -> labels\imagen1166.txt
# Imagen renombrada: images\teknofest_2021_p-4256-_jpg.rf.f7c0368c414e360cf42885d8b4c75b44.jpg -> images\imagen1167.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4256-_jpg.rf.f7c0368c414e360cf42885d8b4c75b44.txt -> labels\imagen1167.txt
# Imagen renombrada: images\teknofest_2021_p-4349-_jpg.rf.0ba1ea4496089224c06b6b145aa2882b.jpg -> images\imagen1168.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4349-_jpg.rf.0ba1ea4496089224c06b6b145aa2882b.txt -> labels\imagen1168.txt
# Imagen renombrada: images\teknofest_2021_p-4392-_jpg.rf.bbf86dd73a13bb40b2f288a22603f791.jpg -> images\imagen1169.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4392-_jpg.rf.bbf86dd73a13bb40b2f288a22603f791.txt -> labels\imagen1169.txt
# Imagen renombrada: images\teknofest_2021_p-446-_jpg.rf.3505ce42cac24792214f9f5259b4e397.jpg -> images\imagen1170.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-446-_jpg.rf.3505ce42cac24792214f9f5259b4e397.txt -> labels\imagen1170.txt
# Imagen renombrada: images\teknofest_2021_p-4560-_jpg.rf.9d8aebcb02e2b4054ef2fb235bc3c660.jpg -> images\imagen1171.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4560-_jpg.rf.9d8aebcb02e2b4054ef2fb235bc3c660.txt -> labels\imagen1171.txt
# Imagen renombrada: images\teknofest_2021_p-4620-_jpg.rf.2dda42416d0b2a7efc7faf89916d6948.jpg -> images\imagen1172.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4620-_jpg.rf.2dda42416d0b2a7efc7faf89916d6948.txt -> labels\imagen1172.txt
# Imagen renombrada: images\teknofest_2021_p-4710-_jpg.rf.1c18e041f09f26d23428e6dad031ca4a.jpg -> images\imagen1173.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4710-_jpg.rf.1c18e041f09f26d23428e6dad031ca4a.txt -> labels\imagen1173.txt
# Imagen renombrada: images\teknofest_2021_p-4753-_jpg.rf.0ce8fc62613243aab7699a9fd3b4a975.jpg -> images\imagen1174.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4753-_jpg.rf.0ce8fc62613243aab7699a9fd3b4a975.txt -> labels\imagen1174.txt
# Imagen renombrada: images\teknofest_2021_p-4767-_jpg.rf.fb94adfab3fc33204ba84227b206fe52.jpg -> images\imagen1175.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4767-_jpg.rf.fb94adfab3fc33204ba84227b206fe52.txt -> labels\imagen1175.txt
# Imagen renombrada: images\teknofest_2021_p-4782-_jpg.rf.b6c872b970030aa9b7f6486db1e8146b.jpg -> images\imagen1176.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4782-_jpg.rf.b6c872b970030aa9b7f6486db1e8146b.txt -> labels\imagen1176.txt
# Imagen renombrada: images\teknofest_2021_p-4842-_jpg.rf.e578a4ba0b20226cb23a38cde089ff7d.jpg -> images\imagen1177.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4842-_jpg.rf.e578a4ba0b20226cb23a38cde089ff7d.txt -> labels\imagen1177.txt
# Imagen renombrada: images\teknofest_2021_p-4844-_jpg.rf.2231f2a50c91493c92ba45f7aa0ef826.jpg -> images\imagen1178.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4844-_jpg.rf.2231f2a50c91493c92ba45f7aa0ef826.txt -> labels\imagen1178.txt
# Imagen renombrada: images\teknofest_2021_p-4857-_jpg.rf.5703b5555b959b18d6535cff3e425e23.jpg -> images\imagen1179.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4857-_jpg.rf.5703b5555b959b18d6535cff3e425e23.txt -> labels\imagen1179.txt
# Imagen renombrada: images\teknofest_2021_p-4901-_jpg.rf.c1614a827ff894fd1391ffaa480fd289.jpg -> images\imagen1180.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-4901-_jpg.rf.c1614a827ff894fd1391ffaa480fd289.txt -> labels\imagen1180.txt
# Imagen renombrada: images\teknofest_2021_p-5024-_jpg.rf.c01136bf1f5eca2b6510c4d0ffdcba00.jpg -> images\imagen1181.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-5024-_jpg.rf.c01136bf1f5eca2b6510c4d0ffdcba00.txt -> labels\imagen1181.txt
# Imagen renombrada: images\teknofest_2021_p-5112-_jpg.rf.a140dfbcd152fc9e170a9cc1c8a0d608.jpg -> images\imagen1182.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-5112-_jpg.rf.a140dfbcd152fc9e170a9cc1c8a0d608.txt -> labels\imagen1182.txt
# Imagen renombrada: images\teknofest_2021_p-5217-_jpg.rf.b0bc1b533f7b353eb8633903f3572e82.jpg -> images\imagen1183.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-5217-_jpg.rf.b0bc1b533f7b353eb8633903f3572e82.txt -> labels\imagen1183.txt
# Imagen renombrada: images\teknofest_2021_p-523-_jpg.rf.076a143f68f5f3a9cad2c155aa4c34b3.jpg -> images\imagen1184.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-523-_jpg.rf.076a143f68f5f3a9cad2c155aa4c34b3.txt -> labels\imagen1184.txt
# Imagen renombrada: images\teknofest_2021_p-5235-_jpg.rf.f87c4ff60ecc8a8315f6a44553d90a60.jpg -> images\imagen1185.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-5235-_jpg.rf.f87c4ff60ecc8a8315f6a44553d90a60.txt -> labels\imagen1185.txt
# Imagen renombrada: images\teknofest_2021_p-5265-_jpg.rf.a1799edfab28c4b8a8a288ef6e46182c.jpg -> images\imagen1186.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-5265-_jpg.rf.a1799edfab28c4b8a8a288ef6e46182c.txt -> labels\imagen1186.txt
# Imagen renombrada: images\teknofest_2021_p-5396-_jpg.rf.4eff75d70a3f6bc04e38ebc512cf4974.jpg -> images\imagen1187.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-5396-_jpg.rf.4eff75d70a3f6bc04e38ebc512cf4974.txt -> labels\imagen1187.txt
# Imagen renombrada: images\teknofest_2021_p-643-_jpg.rf.bdd8c8c9103179d730249f3584e274ab.jpg -> images\imagen1188.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-643-_jpg.rf.bdd8c8c9103179d730249f3584e274ab.txt -> labels\imagen1188.txt
# Imagen renombrada: images\teknofest_2021_p-689-_jpg.rf.b8e0ad80ffaf77af7e5b130bd7f29a63.jpg -> images\imagen1189.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-689-_jpg.rf.b8e0ad80ffaf77af7e5b130bd7f29a63.txt -> labels\imagen1189.txt
# Imagen renombrada: images\teknofest_2021_p-747-_jpg.rf.f156d46a2ab23954f5002dfbf84132a8.jpg -> images\imagen1190.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-747-_jpg.rf.f156d46a2ab23954f5002dfbf84132a8.txt -> labels\imagen1190.txt
# Imagen renombrada: images\teknofest_2021_p-87-_jpg.rf.011b6f327412f9f39826e127ea656189.jpg -> images\imagen1191.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-87-_jpg.rf.011b6f327412f9f39826e127ea656189.txt -> labels\imagen1191.txt
# Imagen renombrada: images\teknofest_2021_p-88-_jpg.rf.bc579335bb76d645cff3c569c2496f8c.jpg -> images\imagen1192.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-88-_jpg.rf.bc579335bb76d645cff3c569c2496f8c.txt -> labels\imagen1192.txt
# Imagen renombrada: images\teknofest_2021_p-929-_jpg.rf.03bea900af9d43dfaa3632b0ec435848.jpg -> images\imagen1193.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-929-_jpg.rf.03bea900af9d43dfaa3632b0ec435848.txt -> labels\imagen1193.txt
# Imagen renombrada: images\teknofest_2021_p-972-_jpg.rf.8c061ed3ccc346a01c3832ae9debac68.jpg -> images\imagen1194.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-972-_jpg.rf.8c061ed3ccc346a01c3832ae9debac68.txt -> labels\imagen1194.txt
# Imagen renombrada: images\teknofest_2021_p-988-_jpg.rf.61d3c756e6d6df69784cf53c106e4ff6.jpg -> images\imagen1195.jpg
# Etiqueta renombrada: labels\teknofest_2021_p-988-_jpg.rf.61d3c756e6d6df69784cf53c106e4ff6.txt -> labels\imagen1195.txt
# Imagen renombrada: images\teknofest_online_sim_cokonemli-22-_jpg.rf.bacad70a616e6dff4d2e82957cb73852.jpg -> images\imagen1196.jpg
# Etiqueta renombrada: labels\teknofest_online_sim_cokonemli-22-_jpg.rf.bacad70a616e6dff4d2e82957cb73852.txt -> labels\imagen1196.txt
# Imagen renombrada: images\visdrone-1201-_jpg.rf.8ffc30d642eebe65169d3d86219c6ab7.jpg -> images\imagen1197.jpg
# Etiqueta renombrada: labels\visdrone-1201-_jpg.rf.8ffc30d642eebe65169d3d86219c6ab7.txt -> labels\imagen1197.txt
# Imagen renombrada: images\visdrone-1455-_jpg.rf.15c93cc4d0f3f77939f357aa954db88c.jpg -> images\imagen1198.jpg
# Etiqueta renombrada: labels\visdrone-1455-_jpg.rf.15c93cc4d0f3f77939f357aa954db88c.txt -> labels\imagen1198.txt
#
# Renombrado completado.

# %% [markdown]
# ## entrenamiento del modelo

# %%
import os
from ultralytics import YOLO
import psutil

def monitor_memory():
    """Imprime el uso de memoria en tiempo real."""
    mem = psutil.virtual_memory()
    print(f"Uso de memoria: {mem.percent}% ({mem.used / 1e9:.2f} GB / {mem.total / 1e9:.2f} GB)")

def main():
    """
    Script para entrenar y evaluar un modelo YOLOv8 utilizando la librería ultralytics.
    """
    # Directorios
    current_dir = os.getcwd()

    # Ruta al archivo data.yaml
    data_file = os.path.join(current_dir, "datasets", "data.yaml")

    # Crear el archivo data.yaml si no existe
    if not os.path.exists(data_file):
        with open(data_file, 'w') as f:
            f.write(f"""
            path: {os.path.join(current_dir, 'datasets')}
            train: images/train
            val: images/val
            names: ['object']
            """)

    # 1. Crear el modelo YOLO
    model = YOLO("yolov8n.pt")

    # Monitoreo de memoria antes del entrenamiento
    print("===== Antes del entrenamiento =====")
    monitor_memory()

    # 2. Entrenar el modelo
    model.train(
        data=data_file,
        epochs=50,
        imgsz=640,
        batch=8,
        name="yolov8_vehicle",
        project="runs",
        pretrained=True
    )

    # Monitoreo de memoria después del entrenamiento
    print("===== Después del entrenamiento =====")
    monitor_memory()

    # 3. Evaluar el modelo con el mejor peso
    best_weights_path = os.path.join("runs", "detect", "yolov8_vehicle", "weights", "best.pt")
    model = YOLO(best_weights_path)

    print("===== Antes de la validación =====")
    monitor_memory()

    metrics = model.val(data=data_file)
    print("===== Resultados de Validación =====")
    print(metrics)

    print("===== Después de la validación =====")
    monitor_memory()

    # 4. Inferencia en el conjunto de test
    test_images_dir = os.path.join(current_dir, "test", "images")

    print("===== Antes de la inferencia =====")
    monitor_memory()

    predictions = model.predict(
        source=test_images_dir,
        conf=0.25,
        save=True,
        name="yolov8_vehicle_test"
    )

    print("===== Inferencia en conjunto de test finalizada =====")
    print(f"Predicciones guardadas en: runs/detect/yolov8_vehicle_test")

    print("===== Después de la inferencia =====")
    monitor_memory()

if __name__ == "__main__":
    main()
# Out:
# ===== Antes del entrenamiento =====
# Uso de memoria: 85.8% (5.42 GB / 6.31 GB)
# New https://pypi.org/project/ultralytics/8.3.93 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.89  Python-3.11.5 torch-2.6.0+cpu CPU (AMD Ryzen 5 3500U with Radeon Vega Mobile Gfx)
# engine\trainer: task=detect, mode=train, model=yolov8n.pt, data=c:\Users\samue\OneDrive\Documentos\GitHub\vision_artificial-main\Aerial View Vehicle Detection.v1i.yolov8\train\datasets\data.yaml, epochs=50, time=None, patience=100, batch=8, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=runs, name=yolov8_vehicle2, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs\yolov8_vehicle2
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 129 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs\yolov8_vehicle2', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# train: Scanning C:\Users\samue\OneDrive\Documentos\GitHub\vision_artificial-main\Aerial View Vehicle Detection.v1i.yolov8\train\datasets\labels\train.cache... 958 images, 0 backgrounds, 0 corrupt: 100%|██████████| 958/958 [00:00<?, ?it/s]
# train: WARNING  C:\Users\samue\OneDrive\Documentos\GitHub\vision_artificial-main\Aerial View Vehicle Detection.v1i.yolov8\train\datasets\images\train\imagen43.jpg: 1 duplicate labels removed
# train: WARNING  C:\Users\samue\OneDrive\Documentos\GitHub\vision_artificial-main\Aerial View Vehicle Detection.v1i.yolov8\train\datasets\images\train\imagen744.jpg: 1 duplicate labels removed
# train: WARNING  C:\Users\samue\OneDrive\Documentos\GitHub\vision_artificial-main\Aerial View Vehicle Detection.v1i.yolov8\train\datasets\images\train\imagen944.jpg: 1 duplicate labels removed
# train: WARNING  C:\Users\samue\OneDrive\Documentos\GitHub\vision_artificial-main\Aerial View Vehicle Detection.v1i.yolov8\train\datasets\images\train\imagen990.jpg: 1 duplicate labels removed
# val: Scanning C:\Users\samue\OneDrive\Documentos\GitHub\vision_artificial-main\Aerial View Vehicle Detection.v1i.yolov8\train\datasets\labels\val.cache... 240 images, 0 backgrounds, 0 corrupt: 100%|██████████| 240/240 [00:00<?, ?it/s]
# val: WARNING  C:\Users\samue\OneDrive\Documentos\GitHub\vision_artificial-main\Aerial View Vehicle Detection.v1i.yolov8\train\datasets\images\val\imagen705.jpg: 1 duplicate labels removed
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
pip install psutil
# Out:
# Requirement already satisfied: psutil in c:\users\samue\appdata\roaming\python\python311\site-packages (5.9.6)Note: you may need to restart the kernel to use updated packages.
